# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('../../data/interim/gurgaon_properties_cleaned_v2.csv').drop_duplicates()

# %%
df.head()
# Out:
#   property_type                      society      sector  price  \
# 0          flat      signature global park 4   sector 36   0.82
# 1          flat             smart world gems   sector 89   0.95
# 2          flat                pyramid elite   sector 86   0.46
# 3          flat       breez global hill view  sohna road   0.32
# 4          flat  bestech park view sanskruti   sector 92   1.60
#
#    price_per_sqft     area                                       areaWithType  \
# 0          7585.0   1081.0  Super Built up area 1081(100.43 sq.m.)Carpet a...
# 1          8600.0   1105.0                   Carpet area: 1103 (102.47 sq.m.)
# 2            79.0  58228.0                 Carpet area: 58141 (5401.48 sq.m.)
# 3          5470.0    585.0  Built Up area: 1000 (92.9 sq.m.)Carpet area: 5...
# 4          8020.0   1995.0  Super Built up area 1995(185.34 sq.m.)Built Up...
#
#    bedRoom  bathroom balcony  floorNum      facing       agePossession  \
# ...

# %%
df.shape
# Out:
# (3677, 23)

# %%
df.columns
# Out:
# Index(['property_type', 'society', 'sector', 'price', 'price_per_sqft', 'area',
#        'areaWithType', 'bedRoom', 'bathroom', 'balcony', 'floorNum', 'facing',
#        'agePossession', 'super_built_up_area', 'built_up_area', 'carpet_area',
#        'study room', 'servant room', 'store room', 'pooja room', 'others',
#        'furnishing_type', 'luxury_score'],
#       dtype='object')

# %%
# outliers on the basis of price column
sns.distplot(df['price'])
# Out:
# C:\Users\vijit_singh\AppData\Local\Temp\ipykernel_2852\2797181776.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price'])
# <Axes: xlabel='price', ylabel='Density'>

# %%
sns.boxplot(x=df['price'])
# Out:
# <Axes: xlabel='price'>

# %%
# Calculate the IQR for the 'price' column
Q1 = df['price'].quantile(0.25)
Q3 = df['price'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers = df[(df['price'] < lower_bound) | (df['price'] > upper_bound)]

# Displaying the number of outliers and some statistics
num_outliers = outliers.shape[0]
outliers_price_stats = outliers['price'].describe()

num_outliers, outliers_price_stats
# Out:
# (425,
#  count    425.000000
#  mean       9.235624
#  std        4.065259
#  min        5.460000
#  25%        6.460000
#  50%        8.000000
#  75%       10.750000
#  max       31.500000
#  Name: price, dtype: float64)

# %%
outliers.sort_values('price',ascending=False).head(20)
# Out:
#      property_type                                            society  \
# 821          house  arjun marg/ sector- 26 phase- 1/ golf course road
# 2834         house                                        independent
# 2488         house                                     dlf city plots
# 2211         house                                        independent
# 1686         house                                   suncity township
# 3046         house                             emaar the palm springs
# 2765         house                                        independent
# 2667         house                                 vipul tatvam villa
# 2096         house                             luxury dlf city floors
# 711          house                                        independent
# 874          house                                     dlf city plots
# 1687         house                                        independent
# ...

# %%
# on the basis of price col we can say that there are some genuine outliers but there are some data erros as well
# lets try to do outlier detection in other columns as well.

# %% [markdown]
# ### Price_per_sqft

# %%
sns.distplot(df['price_per_sqft'])
# Out:
# C:\Users\vijit_singh\AppData\Local\Temp\ipykernel_2852\2186227091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
# Calculate the IQR for the 'price' column
Q1 = df['price_per_sqft'].quantile(0.25)
Q3 = df['price_per_sqft'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Identify outliers
outliers_sqft = df[(df['price_per_sqft'] < lower_bound) | (df['price_per_sqft'] > upper_bound)]

# Displaying the number of outliers and some statistics
num_outliers = outliers_sqft.shape[0]
outliers_sqft_stats = outliers_sqft['price_per_sqft'].describe()

num_outliers, outliers_sqft_stats
# Out:
# (354,
#  count       354.000000
#  mean      52592.612994
#  std       61150.458507
#  min       24489.000000
#  25%       28208.250000
#  50%       33368.500000
#  75%       41982.250000
#  max      600000.000000
#  Name: price_per_sqft, dtype: float64)

# %% [markdown]
# - there is a data error in this, price per sqrft created by multiplying area and the price column, assuming area is in sqft was given. after analysis it is found the in some records area is in sqyard instead of sqft. therefore we have to correct this data error.

# %%
outliers_sqft['area'] = outliers_sqft['area'].apply(lambda x:x*9 if x<1000 else x)
# Out:
# C:\Users\vijit_singh\AppData\Local\Temp\ipykernel_2852\205471443.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_sqft['area'] = outliers_sqft['area'].apply(lambda x:x*9 if x<1000 else x)

# %%
outliers_sqft['price_per_sqft'] = round((outliers_sqft['price']*10000000)/outliers_sqft['area'])
# Out:
# C:\Users\vijit_singh\AppData\Local\Temp\ipykernel_2852\3686006548.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_sqft['price_per_sqft'] = round((outliers_sqft['price']*10000000)/outliers_sqft['area'])

# %%
outliers_sqft['price_per_sqft'].describe()
# Out:
# count      354.000000
# mean     29357.906780
# std      12403.077309
# min       2723.000000
# 25%      25562.000000
# 50%      29870.500000
# 75%      35549.500000
# max      82540.000000
# Name: price_per_sqft, dtype: float64

# %%
df.update(outliers_sqft)

# %%
sns.distplot(df['price_per_sqft'])
# Out:
# C:\Users\vijit_singh\AppData\Local\Temp\ipykernel_2852\2186227091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
df[df['price_per_sqft']>50000]
# Out:
#      property_type                       society      sector  price  \
# 386          house            cloudnine cottages  sohna road   5.50
# 671          house            emaar mgf marbella   sector 66  18.00
# 1200         house                   independent   sector 26  14.75
# 1261         house                   independent   sector 25  16.00
# 1349          flat                unitech vistas   sector 70   9.00
# 1425         house  project housing board colony   sector 31   8.00
# 1640         house        emaar the palm springs   sector 54  14.00
# 1839         house                unitech escape   sector 50  10.80
# 2211         house                   independent   sector 26  26.00
# 2290         house                  malibu towne   sector 47   8.50
# 2488         house                dlf city plots   sector 26  26.00
# 3046         house        emaar the palm springs   sector 54  24.00
# 3285         house                           nul   sector 28  12.50
#
# ...

# %% [markdown]
# - there are 13 values where we can consider them actual outliers

# %%
df = df[df['price_per_sqft'] <= 50000]

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %% [markdown]
# ### Area

# %%
sns.histplot(df['area'],kde=True)
# Out:
# <Axes: xlabel='area', ylabel='Count'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df['area'].describe()
# Out:
# count      3647.000000
# mean       2947.723608
# std       23208.194102
# min         145.000000
# 25%        1262.000000
# 50%        1750.000000
# 75%        2350.000000
# max      875000.000000
# Name: area, dtype: float64

# %%
df[df['area'] > 100000]
# Out:
#      property_type                    society      sector  price  \
# 1638          flat  signature global solera 2  sector 107   0.51
# 1648          flat          hcbs sports ville  sohna road   0.35
# 2111          flat      signature the roselia   sector 95   0.45
# 2651          flat            ramsons kshitij   sector 95   0.31
# 3021         house                independent   sector 50   5.00
#
#       price_per_sqft      area                           areaWithType  \
# 1638             9.0  566667.0   Carpet area: 514396 (47788.95 sq.m.)
# 1648             4.0  875000.0  Built Up area: 737147 (68483.2 sq.m.)
# 2111             7.0  642857.0   Carpet area: 569243 (52884.41 sq.m.)
# 2651             5.0  620000.0    Carpet area: 607936 (56479.1 sq.m.)
# 3021           232.0  215517.0             Plot area 2(1011.71 sq.m.)
#
#       bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# 1638        2         2       1       3.0       North    New Property
# ...

# %% [markdown]
# - remove those who have area less than 100000

# %%
df = df[df['area'] < 100000]

# %%
sns.distplot(df['area'])
# Out:
# C:\Users\vijit_singh\AppData\Local\Temp\ipykernel_2852\91062565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %% [markdown]
# - manually checking whether are is justifying other columns as well or not. for eg: bedrooms, bothrooms etc.

# %%
df[df['area'] > 10000].sort_values('area',ascending=False)

# these indexes are having data entry errors
# 818, 1796, 1123, 2, 2356, 115, 3649, 2503, 1471
# Out:
#      property_type                    society      sector  price  \
# 818          house                independent   sector 26  18.40
# 48           house  ganpati heights apartment   sector 13   1.25
# 1123          flat                 rof ananda   sector 95   0.38
# 1796          flat                 rof ananda   sector 95   0.38
# 300          house      dlf city plot phase 4   sector 28  13.00
# 2             flat              pyramid elite   sector 86   0.46
# 2356          flat                 rof ananda   sector 95   0.33
# 115           flat      signature the serenas  sohna road   0.28
# 2666         house                independent   sector 25   7.30
# 3649          flat            ramsons kshitij   sector 95   0.24
# 2503          flat                 rof ananda   sector 95   0.21
# 1358         house                independent   sector 57   6.25
# 3195         house                independent   sector 43   5.50
# ...

# %%
df.drop(index=[818, 1796, 1123, 2, 2356, 115, 3649, 2503, 1471], inplace=True)

# %%
df[df['area'] > 10000].sort_values('area',ascending=False)
# Out:
#      property_type                    society      sector  price  \
# 48           house  ganpati heights apartment   sector 13   1.25
# 300          house      dlf city plot phase 4   sector 28  13.00
# 2666         house                independent   sector 25   7.30
# 1358         house                independent   sector 57   6.25
# 3195         house                independent   sector 43   5.50
# 2131          flat                 godrej air   sector 85   2.50
# 3088         house       unitech aspen greens   sector 50   6.95
# 3444          flat                godrej icon  sector 88a   1.75
# 2834         house                independent   sector 43  27.50
# 2342          flat             m3m golfestate   sector 65  13.20
# 747          house                independent  sohna road   5.50
#
#       price_per_sqft     area  \
# 48             151.0  82781.0
# 300           1992.0  65261.0
# 2666          1560.0  46795.0
# 1358          2778.0  22498.0
# ...

# %% [markdown]
# - in some records area is wrong we can fix it using carpet and builtup area

# %%
df.loc[48,'area'] = 115*9
df.loc[300,'area'] = 7250
df.loc[2666,'area'] = 5800
df.loc[1358,'area'] = 2660
df.loc[3195,'area'] = 2850
df.loc[2131,'area'] = 1812
df.loc[3088,'area'] = 2160
df.loc[3444,'area'] = 1175

# %%
sns.distplot(df['area'])
# Out:
# C:\Users\vijit_singh\AppData\Local\Temp\ipykernel_2852\91062565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %% [markdown]
# - we can not remove these because these are genuine points

# %%
df['area'].describe()
# Out:
# count     3633.000000
# mean      1950.357005
# std       1215.707897
# min        145.000000
# 25%       1260.000000
# 50%       1747.000000
# 75%       2325.000000
# max      11286.000000
# Name: area, dtype: float64

# %% [markdown]
# ### Bedroom

# %%
sns.distplot(df['bedRoom'])
# Out:
# C:\Users\vijit_singh\AppData\Local\Temp\ipykernel_2852\1691983684.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bedRoom'])
# <Axes: xlabel='bedRoom', ylabel='Density'>

# %%
sns.boxplot(x=df['bedRoom'])
# Out:
# <Axes: xlabel='bedRoom'>

# %%
df['bedRoom'].describe()
# Out:
# count    3633.000000
# mean        3.333609
# std         1.830035
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        21.000000
# Name: bedRoom, dtype: float64

# %% [markdown]
# - keeping on ly less than 10 bedrooms

# %%
df[df['bedRoom'] > 10].sort_values('bedRoom',ascending=False)
# Out:
#      property_type                      society      sector  price  \
# 3618         house                  independent   sector 54   5.00
# 2611         house                  independent   sector 43   4.50
# 1493         house                  independent   sector 17   3.93
# 78           house                  independent   sector 17   3.87
# 19           house                  independent   sector 54   5.50
# 1381         house                private house   sector 55   7.05
# 2096         house       luxury dlf city floors   sector 26  20.00
# 3457         house                  independent   sector 56  12.39
# 2137         house                  independent   sector 40  12.00
# 2039         house                  independent   sector 43  13.50
# 372          house                  independent   sector 11   4.50
# 874          house               dlf city plots   sector 26  20.00
# 3698         house                  independent   sector 55   9.19
# ...

# %%
df = df[df['bedRoom'] <= 10]

# %%
df.shape
# Out:
# (3588, 23)

# %%
sns.distplot(df['bedRoom'])
# Out:
# C:\Users\vijit_singh\AppData\Local\Temp\ipykernel_2852\1691983684.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bedRoom'])
# <Axes: xlabel='bedRoom', ylabel='Density'>

# %%
sns.boxplot(x=df['bedRoom'])
# Out:
# <Axes: xlabel='bedRoom'>

# %%
df['bedRoom'].describe()
# Out:
# count    3588.000000
# mean        3.203735
# std         1.393968
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        10.000000
# Name: bedRoom, dtype: float64

# %% [markdown]
# ### Bathroom

# %%
sns.distplot(df['bathroom'])
# Out:
# C:\Users\vijit_singh\AppData\Local\Temp\ipykernel_2852\2904465235.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bathroom'])
# <Axes: xlabel='bathroom', ylabel='Density'>

# %%
sns.boxplot(x=df['bathroom'])
# Out:
# <Axes: xlabel='bathroom'>

# %%
df[df['bathroom'] > 10].sort_values('bathroom',ascending=False)
# Out:
#      property_type               society     sector  price  price_per_sqft  \
# 3267         house  adani brahma samsara  sector 60  18.02         28200.0
# 2771         house           independent  sector 39   7.00         10000.0
# 2816         house           independent  sector 24  11.00         28902.0
#
#         area                                       areaWithType  bedRoom  \
# 3267  6390.0                 Built Up area: 6390 (593.65 sq.m.)        9
# 2771  7000.0  Plot area 350(32.52 sq.m.)Built Up area: 7000 ...       10
# 2816  3806.0  Plot area 3806.45(353.63 sq.m.)Built Up area: ...        8
#
#       bathroom balcony  floorNum      facing   agePossession  \
# 3267        12      3+       3.0  North-East  Relatively New
# 2771        11      3+       4.0  South-East  Relatively New
# 2816        11      3+       3.0        East    Old Property
#
#       super_built_up_area  built_up_area  carpet_area  study room  \
# ...

# %% [markdown]
# - These records seems logical so we are not removing them

# %%
df.head()
# Out:
#   property_type                      society      sector  price  \
# 0          flat      signature global park 4   sector 36   0.82
# 1          flat             smart world gems   sector 89   0.95
# 3          flat       breez global hill view  sohna road   0.32
# 4          flat  bestech park view sanskruti   sector 92   1.60
# 5          flat               suncity avenue  sector 102   0.48
#
#    price_per_sqft    area                                       areaWithType  \
# 0          7585.0  1081.0  Super Built up area 1081(100.43 sq.m.)Carpet a...
# 1          8600.0  1105.0                   Carpet area: 1103 (102.47 sq.m.)
# 3          5470.0   585.0  Built Up area: 1000 (92.9 sq.m.)Carpet area: 5...
# 4          8020.0  1995.0  Super Built up area 1995(185.34 sq.m.)Built Up...
# 5          9022.0   532.0  Super Built up area 632(58.71 sq.m.)Carpet are...
#
#    bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# ...

# %% [markdown]
# ### super built up area

# %%
sns.distplot(df['super_built_up_area'])
# Out:
# C:\Users\vijit_singh\AppData\Local\Temp\ipykernel_2852\4184943455.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['super_built_up_area'])
# <Axes: xlabel='super_built_up_area', ylabel='Density'>

# %%
sns.boxplot(x=df['super_built_up_area'])
# Out:
# <Axes: xlabel='super_built_up_area'>

# %%
df['super_built_up_area'].describe()
# Out:
# count     1875.000000
# mean      1925.237627
# std        764.172177
# min         89.000000
# 25%       1479.500000
# 50%       1828.000000
# 75%       2215.000000
# max      10000.000000
# Name: super_built_up_area, dtype: float64

# %%
df[df['super_built_up_area'] > 6000]
# Out:
#      property_type                      society       sector  price  \
# 1323          flat  bestech park view grand spa    sector 81    4.7
# 3265          flat       krrish provence estate  gwal pahari    7.5
#
#       price_per_sqft     area                             areaWithType  \
# 1323          6786.0   6926.0   Super Built up area 6926(643.45 sq.m.)
# 3265          7500.0  10000.0  Super Built up area 10000(929.03 sq.m.)
#
#       bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# 1323        4         4      3+      19.0       North  Relatively New
# 3265        5         6      3+      23.0  North-East  Relatively New
#
#       super_built_up_area  built_up_area  carpet_area  study room  \
# 1323               6926.0            NaN          NaN           0
# 3265              10000.0            NaN          NaN           0
#
#       servant room  store room  pooja room  others  furnishing_type  \
# ...

# %% [markdown]
# - These are genuine datapoints.

# %% [markdown]
# ### built up area

# %%
sns.distplot(df['built_up_area'])
# Out:
# C:\Users\vijit_singh\AppData\Local\Temp\ipykernel_2852\3494228458.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['built_up_area'])
# <Axes: xlabel='built_up_area', ylabel='Density'>

# %%
sns.boxplot(x=df['built_up_area'])
# Out:
# <Axes: xlabel='built_up_area'>

# %%
df[df['built_up_area'] > 10000]
# Out:
#      property_type      society     sector  price  price_per_sqft     area  \
# 2834         house  independent  sector 43   27.5         24366.0  11286.0
#
#                       areaWithType  bedRoom  bathroom balcony  floorNum  \
# 2834  Plot area 1254(1048.5 sq.m.)        6         7      3+       3.0
#
#           facing   agePossession  super_built_up_area  built_up_area  \
# 2834  North-East  Relatively New                  NaN        11286.0
#
#       carpet_area  study room  servant room  store room  pooja room  others  \
# 2834          NaN           1             1           0           1       1
#
#       furnishing_type  luxury_score
# 2834                1            42

# %% [markdown]
# - this records seems logical as well

# %% [markdown]
# ### carpet area

# %%
sns.distplot(df['carpet_area'])
# Out:
# C:\Users\vijit_singh\AppData\Local\Temp\ipykernel_2852\3905767603.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['carpet_area'])
# <Axes: xlabel='carpet_area', ylabel='Density'>

# %%
sns.boxplot(x=df['carpet_area'])
# Out:
# <Axes: xlabel='carpet_area'>

# %%
df[df['carpet_area'] > 10000]
# Out:
#      property_type         society     sector  price  price_per_sqft     area  \
# 2131          flat      godrej air  sector 85    2.5          1379.0   1812.0
# 2342          flat  m3m golfestate  sector 65   13.2         12000.0  11000.0
#
#                             areaWithType  bedRoom  bathroom balcony  floorNum  \
# 2131  Carpet area: 18122 (1683.59 sq.m.)        4         5      3+      16.0
# 2342  Carpet area: 11000 (1021.93 sq.m.)        4         4       3      13.0
#
#           facing       agePossession  super_built_up_area  built_up_area  \
# 2131  North-East  Under Construction                  NaN            NaN
# 2342       North      Moderately Old                  NaN            NaN
#
#       carpet_area  study room  servant room  store room  pooja room  others  \
# 2131      18122.0           1             0           0           1       1
# 2342      11000.0           0             1           0           0       0
#
#       furnishing_type  luxury_score
# ...

# %% [markdown]
# - extra 2 in carpet area on index 2131

# %%
df.loc[2131,'carpet_area'] = 1812

# %%
df[df['carpet_area'] > 10000]
# Out:
#      property_type         society     sector  price  price_per_sqft     area  \
# 2342          flat  m3m golfestate  sector 65   13.2         12000.0  11000.0
#
#                             areaWithType  bedRoom  bathroom balcony  floorNum  \
# 2342  Carpet area: 11000 (1021.93 sq.m.)        4         4       3      13.0
#
#      facing   agePossession  super_built_up_area  built_up_area  carpet_area  \
# 2342  North  Moderately Old                  NaN            NaN      11000.0
#
#       study room  servant room  store room  pooja room  others  \
# 2342           0             1           0           0       0
#
#       furnishing_type  luxury_score
# 2342                0            60

# %%
df.head()
# Out:
#   property_type                      society      sector  price  \
# 0          flat      signature global park 4   sector 36   0.82
# 1          flat             smart world gems   sector 89   0.95
# 3          flat       breez global hill view  sohna road   0.32
# 4          flat  bestech park view sanskruti   sector 92   1.60
# 5          flat               suncity avenue  sector 102   0.48
#
#    price_per_sqft    area                                       areaWithType  \
# 0          7585.0  1081.0  Super Built up area 1081(100.43 sq.m.)Carpet a...
# 1          8600.0  1105.0                   Carpet area: 1103 (102.47 sq.m.)
# 3          5470.0   585.0  Built Up area: 1000 (92.9 sq.m.)Carpet area: 5...
# 4          8020.0  1995.0  Super Built up area 1995(185.34 sq.m.)Built Up...
# 5          9022.0   532.0  Super Built up area 632(58.71 sq.m.)Carpet are...
#
#    bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# ...

# %%
sns.distplot(df['luxury_score'])
# Out:
# C:\Users\vijit_singh\AppData\Local\Temp\ipykernel_2852\3385064764.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['luxury_score'])
# <Axes: xlabel='luxury_score', ylabel='Density'>

# %% [markdown]
# ### Luxury score

# %%
sns.boxplot(df['luxury_score'])
# Out:
# <Axes: ylabel='luxury_score'>

# %%
df.shape
# Out:
# (3588, 23)

# %% [markdown]
# ### Price per Sqft

# %%
df['price_per_sqft'] = round((df['price']*10000000)/df['area'])

# %%
df.head()
# Out:
#   property_type                      society      sector  price  \
# 0          flat      signature global park 4   sector 36   0.82
# 1          flat             smart world gems   sector 89   0.95
# 3          flat       breez global hill view  sohna road   0.32
# 4          flat  bestech park view sanskruti   sector 92   1.60
# 5          flat               suncity avenue  sector 102   0.48
#
#    price_per_sqft    area                                       areaWithType  \
# 0          7586.0  1081.0  Super Built up area 1081(100.43 sq.m.)Carpet a...
# 1          8597.0  1105.0                   Carpet area: 1103 (102.47 sq.m.)
# 3          5470.0   585.0  Built Up area: 1000 (92.9 sq.m.)Carpet area: 5...
# 4          8020.0  1995.0  Super Built up area 1995(185.34 sq.m.)Built Up...
# 5          9023.0   532.0  Super Built up area 632(58.71 sq.m.)Carpet are...
#
#    bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# ...

# %%
sns.distplot(df['price_per_sqft'])
# Out:
# C:\Users\vijit_singh\AppData\Local\Temp\ipykernel_2852\2186227091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
sns.boxplot(df['price_per_sqft'])
# Out:
# <Axes: ylabel='price_per_sqft'>

# %%
df[df['price_per_sqft'] > 42000]
# Out:
#      property_type                       society      sector  price  \
# 711          house                   independent   sector 26   20.0
# 901          house                   independent   sector 28   12.0
# 1090         house                   independent  sector 105    9.9
# 1509         house                   independent   sector 55    5.0
# 1526         house                dlf city plots   sector 26   19.0
# 2040         house                   independent   sector 43    9.5
# 2130         house                   independent   sector 26   19.0
# 3054         house  sushant lok 1 builder floors   sector 43   13.0
# 3108         house                   independent   sector 25   13.0
#
#       price_per_sqft    area  \
# 711          44444.0  4500.0
# 901          42194.0  2844.0
# 1090         49500.0  2000.0
# 1509         44444.0  1125.0
# 1526         42054.0  4518.0
# 2040         42222.0  2250.0
# 2130         42222.0  4500.0
# 3054         48148.0  2700.0
# ...

# %% [markdown]
# - index 711, we have seen in the EDA that sector 26 houses are ususaly expensive therefore we can not consider them outlier.
# - index 1509, if you campare bedroom and area this seems outlier

# %%
x = df[df['price_per_sqft'] <= 20000]
(x['area']/x['bedRoom']).quantile(0.02)
# Out:
# np.float64(183.33333333333334)

# %% [markdown]
# - there are 2% of the data points which are having area per bedroom less than 183

# %% [markdown]
# - lets see those houses which are having less than this ratio

# %%
df[(df['area']/df['bedRoom'])<183]
# Out:
#      property_type                                 society      sector  price  \
# 37           house                             independent  sector 104   0.45
# 48           house               ganpati heights apartment   sector 13   1.25
# 93           house                             independent  sector 105   1.10
# 99           house                             independent    sector 4   1.10
# 186          house                             independent   sector 13   1.50
# ...            ...                                     ...         ...    ...
# 3686         house                             independent   sector 12   0.90
# 3713         house                             independent   sector 41   4.25
# 3751         house                             independent   sector 21   0.45
# 3774         house                             independent   sector 28   0.45
# 3797         house  surendra homes dayaindependentd colony    sector 6   0.75
#
#       price_per_sqft    area  \
# ...

# %%
(x['area']/x['bedRoom']).quantile(0.05)
# Out:
# np.float64(250.5)

# %%
df[(df['area']/df['bedRoom'])<183].sample(5).sort_values('price_per_sqft',ascending=False)
# Out:
#      property_type        society      sector  price  price_per_sqft   area  \
# 1429         house  sector 38 rwa   sector 38   1.40         23932.0  585.0
# 3751         house    independent   sector 21   0.45          8411.0  535.0
# 3306         house    independent    sector 4   0.50         10482.0  477.0
# 2313         house      prem kunj  sohna road   0.50          7407.0  675.0
# 2559         house      row house  sector 105   0.43          9130.0  471.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 1429  Plot area 65(54.35 sq.m.)Built Up area: 62 sq....        8         8
# 3751                      Carpet area: 535 (49.7 sq.m.)        3         2
# 3306                    Built Up area: 53 (44.31 sq.m.)        5         3
# 2313  Plot area 675(62.71 sq.m.)Built Up area: 725 s...        5         4
# 2559  Plot area 52(43.48 sq.m.)Built Up area: 1050 s...        3         3
#
# ...

# %% [markdown]
# There could be two possibilited
#
# 1. by mistake broker labeld them as a house insead of plot because in plots you can have multiple floors it can add up to these number of rooms
# 2. these are actully houses with multiple floors total bedrooms in all the floors are mentoned.

# %%
(df['area'] / df['bedRoom']).sort_values(ascending=True)
# Out:
# 2784      51.428571
# 2300      64.285714
# 2360      67.500000
# 2047      67.500000
# 1562      72.000000
#            ...
# 1879    3215.000000
# 1683    3333.333333
# 747     3599.666667
# 662     3800.000000
# 2548    3801.500000
# Length: 3588, dtype: float64

# %%
df['area_room_ratio'] = df['area'] / df['bedRoom']

# %%
df[df['area_room_ratio'] < 250].sort_values(by = 'area_room_ratio',ascending=True)
# Out:
#      property_type                          society      sector  price  \
# 2784         house                      independent   sector 28   0.75
# 2300         house  ashok vihar phase iii extension    sector 5   0.40
# 2360         house                      independent  sector 105   0.60
# 2047         house                            ansal   sector 43   1.85
# 1562         house                      independent    sector 6   0.50
# ...            ...                              ...         ...    ...
# 3070          flat            pyramid urban homes 2   sector 86   0.41
# 209           flat            pyramid urban homes 2   sector 86   0.42
# 2380          flat                      zara aavaas  sector 104   0.49
# 1529          flat                    prime habitat   sector 99   0.27
# 2353          flat          signature global solera  sector 107   0.28
#
#       price_per_sqft   area  \
# 2784         20833.0  360.0
# 2300          8889.0  450.0
# ...

# %%
g = sns.lmplot(x='area',y='bedRoom',data=df)
plt.plot(1000, df['bedRoom'].max() - 1, 'ro', markersize=100, fillstyle='none')

# %% [markdown]
# - lets find out these datapoints which are in red circle

# %%
df[df['area_room_ratio'] < 100].sort_values(by = 'area_room_ratio',ascending=True)
# Out:
#      property_type                          society      sector  price  \
# 2784         house                      independent   sector 28   0.75
# 2300         house  ashok vihar phase iii extension    sector 5   0.40
# 2360         house                      independent  sector 105   0.60
# 2047         house                            ansal   sector 43   1.85
# 1562         house                      independent    sector 6   0.50
# 751          house                      independent   sector 17   0.32
# 1580         house                      independent    sector 8   0.49
# 1429         house                    sector 38 rwa   sector 38   1.40
# 1953         house                   not applicable    sector 4   0.51
# 2721         house                      independent    sector 5   0.50
# 1696         house                         ss omnia   sector 86   0.42
# 1737         house            rajendra park gurgaon  sector 105   0.37
# ...

# %%
df[df['area_room_ratio'] < 100].sort_values(by = 'area_room_ratio',ascending=True).shape[0]
# Out:
# 20

# %% [markdown]
# - lets remove these 20 points

# %%
df = df[df['area_room_ratio'] > 100]

# %%
df[(df['area_room_ratio'] < 250) & (df['bedRoom'] > 3)]
# Out:
#      property_type                                 society      sector  price  \
# 9            house                             independent  sector 105   1.20
# 15           house                             independent   sector 12   1.20
# 48           house               ganpati heights apartment   sector 13   1.25
# 74           house                             independent   sector 25   7.60
# 93           house                             independent  sector 105   1.10
# ...            ...                                     ...         ...    ...
# 3633         house                             independent   sector 17   0.32
# 3686         house                             independent   sector 12   0.90
# 3713         house                             independent   sector 41   4.25
# 3738         house                             independent    sector 7   1.16
# 3797         house  surendra homes dayaindependentd colony    sector 6   0.75
#
#       price_per_sqft    area  \
# ...

# %% [markdown]
# - in the second reson which is mentioned above, that these houses room could be addition of all the floors, therefore we can bedrooms/floors

# %%
outliers_df = df[(df['area_room_ratio'] < 250) & (df['bedRoom'] > 3)]

# %%
outliers_df['bedRoom'] = round(outliers_df['bedRoom']/outliers_df['floorNum'])
# Out:
# C:\Users\vijit_singh\AppData\Local\Temp\ipykernel_2852\3450078040.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_df['bedRoom'] = round(outliers_df['bedRoom']/outliers_df['floorNum'])

# %%
df.update(outliers_df)

# %%
df['area_room_ratio'] = df['area']/df['bedRoom']
# Out:
# C:\Users\vijit_singh\AppData\Local\Temp\ipykernel_2852\465686754.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['area_room_ratio'] = df['area']/df['bedRoom']

# %%
df[(df['area_room_ratio'] < 250) & (df['bedRoom'] > 4)]
# Out:
#      property_type               society      sector  price  price_per_sqft  \
# 93           house           independent  sector 105   1.10         12222.0
# 387          house           independent   sector 12   0.65          6500.0
# 753          house              shivpuri    sector 7   2.80         12444.0
# 1106         house           independent    sector 5   0.85          9444.0
# 1206         house           independent    sector 7   1.16         11717.0
# 1747         house           independent   sector 12   2.50         13889.0
# 1936         house           independent   sector 11   3.50         15556.0
# 1939         house           independent     manesar   1.10          6173.0
# 2806         house           independent    sector 2   0.98          9074.0
# 3148         house  bhim nagar, sector 6    sector 6   0.85         14096.0
# 3246         house           independent     manesar   0.80          6667.0
# ...

# %%
df[(df['area_room_ratio'] < 250) & (df['bedRoom'] > 4)].shape[0]
# Out:
# 13

# %%
df= df[~((df['area_room_ratio'] < 250) & (df['bedRoom'] > 4))]

# %%
sns.lmplot(x='area',y='bedRoom',data=df)

# %%
# df.to_csv`('../../data/interim/gurgaon_properties_outlier_treated.csv',index=False)
